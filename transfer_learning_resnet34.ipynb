# %% [markdown]
# # Transfer Learning with PyTorch
#
# In this notebook, I will show you how to use transfer learning to train a model on a dataset that is different from the one it was originally trained on.
#
# - Foundataion Model: [Resnet34](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet34.html)
# - Original Dataset: [ImageNet](https://www.image-net.org/)
# - New Dataset: [Cat and Dog](https://www.kaggle.com/datasets/tongpython/cat-and-dog)

# %% [markdown]
# # Download Dataset
#
# Download Cat Dog dataset from [One Drive](https://ncku365-my.sharepoint.com/:u:/g/personal/nm6121030_ncku_edu_tw/EbTwo26N_lZOgDCca7v03YwBH-qgc2hpg3hWsHZ_yzgZWQ?e=PseGN4) and extract it to the current directory.

# %%
import os

if os.path.exists("cat_dog_kaggle"):
    print('Dataset already downloaded and extracted')
else:
    # !bash download_dataset.sh
# Out:
# Dataset already downloaded and extracted

# %% [markdown]
# # Download the package

# %%
# %pip  install -r requirements.txt
# Out:
# Requirement already satisfied: ipykernel in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: matplotlib in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (3.9.2)
# Requirement already satisfied: numpy in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: torch in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: torchvision in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: pillow in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (10.4.0)
# Requirement already satisfied: tqdm in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (4.66.5)
# Requirement already satisfied: torchsummary in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: comm>=0.1.1 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: psutil in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (6.4.5)
# Requirement already satisfied: filelock in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (4.11.0)
# Requirement already satisfied: sympy in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (1.13.2)
# Requirement already satisfied: networkx in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: jinja2 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: fsspec in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (2024.9.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 2)) (3.20.1)
# Requirement already satisfied: decorator in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: stack-data in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: exceptiongroup in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 1)) (4.3.2)
# Requirement already satisfied: six>=1.5 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from jinja2->torch->-r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from sympy->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Visualize the data

# %%
import matplotlib.pyplot as plt
import PIL

cat_img_path = './cat_dog_kaggle/training_set/cats/cat.1.jpg'
dog_img_path = './cat_dog_kaggle/training_set/dogs/dog.1.jpg'

cat_img = PIL.Image.open(cat_img_path)
dog_img = PIL.Image.open(dog_img_path)

plt.figure(figsize=(10, 5))
# Cat
plt.subplot(1, 2, 1)
plt.imshow(cat_img)
plt.title('Cat')
plt.axis('off')
# Dog
plt.subplot(1, 2, 2)
plt.imshow(dog_img)
plt.title('Dog')
plt.axis('off')
plt.show()

# %% [markdown]
# # Create Dataset and DataLoader

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from tqdm import tqdm
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
from torchsummary import summary

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
train_dataset = datasets.ImageFolder(root='cat_dog_kaggle/training_set', transform=transform)
test_dataset = datasets.ImageFolder(root='cat_dog_kaggle/test_set', transform=transform)

# %%
print(f"Training set:")
print(f"Number of images: {len(train_dataset)}")
print(f"Number of classes: {len(train_dataset.classes)}")
print(f"Classes: {train_dataset.classes}")
# show the len of each class
print(f"Dataset distribution:")
print(f"{train_dataset.classes[0]}: {train_dataset.targets.count(0)}")
print(f"{train_dataset.classes[1]}: {train_dataset.targets.count(1)}")

print("="*20)

print(f"Test set:")
print(f"Number of images: {len(test_dataset)}")
print(f"Number of classes: {len(test_dataset.classes)}")
print(f"Classes: {test_dataset.classes}")
# show the len of each class
print(f"Dataset distribution:")
print(f"{test_dataset.classes[0]}: {test_dataset.targets.count(0)}")
print(f"{test_dataset.classes[1]}: {test_dataset.targets.count(1)}")
# Out:
# Training set:
# Number of images: 8005
# Number of classes: 2
# Classes: ['cats', 'dogs']
# Dataset distribution:
# cats: 4000
# dogs: 4005
# ====================
# Test set:
# Number of images: 2023
# Number of classes: 2
# Classes: ['cats', 'dogs']
# Dataset distribution:
# cats: 1011
# dogs: 1012

# %%
# split the train dataset into 80% train and 20% validation
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
# split
train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

print(f"Train dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")    # test set remains the same
# Out:
# Train dataset size: 6404
# Validation dataset size: 1601
# Test dataset size: 2023

# %%
# dataloaders
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=8)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=8)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=8)

# %% [markdown]
# # Import Foundation Model
#
# Resnet34(Very Deep Convolutional Network)
#
# Model Structure:
#
#
# ![image.png](attachment:image.png)

# %%
# check device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} device')
# Out:
# Using cuda device

# %%
import torchvision.models as models
from torchvision.models import resnet34

# Load the pre-trained ResNet34 model
model = resnet34(pretrained=True).to(device)
# Out:
# /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/wsad1232885/anaconda3/envs/py-3.9/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# show the model architecture
summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-20           [-1, 64, 56, 56]             128
#              ReLU-21           [-1, 64, 56, 56]               0
#            Conv2d-22           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-23           [-1, 64, 56, 56]             128
#              ReLU-24           [-1, 64, 56, 56]               0
#        BasicBlock-25           [-1, 64, 56, 56]               0
#            Conv2d-26          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-27          [-1, 128, 28, 28]             256
#              ReLU-28          [-1, 128, 28, 28]               0
#            Conv2d-29          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-30          [-1, 128, 28, 28]             256
#            Conv2d-31          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-36          [-1, 128, 28, 28]             256
#              ReLU-37          [-1, 128, 28, 28]               0
#            Conv2d-38          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-39          [-1, 128, 28, 28]             256
#              ReLU-40          [-1, 128, 28, 28]               0
#        BasicBlock-41          [-1, 128, 28, 28]               0
#            Conv2d-42          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-43          [-1, 128, 28, 28]             256
#              ReLU-44          [-1, 128, 28, 28]               0
#            Conv2d-45          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-46          [-1, 128, 28, 28]             256
#              ReLU-47          [-1, 128, 28, 28]               0
#        BasicBlock-48          [-1, 128, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#        BasicBlock-55          [-1, 128, 28, 28]               0
#            Conv2d-56          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-57          [-1, 256, 14, 14]             512
#              ReLU-58          [-1, 256, 14, 14]               0
#            Conv2d-59          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-60          [-1, 256, 14, 14]             512
#            Conv2d-61          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-62          [-1, 256, 14, 14]             512
#              ReLU-63          [-1, 256, 14, 14]               0
#        BasicBlock-64          [-1, 256, 14, 14]               0
#            Conv2d-65          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-66          [-1, 256, 14, 14]             512
#              ReLU-67          [-1, 256, 14, 14]               0
#            Conv2d-68          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-69          [-1, 256, 14, 14]             512
#              ReLU-70          [-1, 256, 14, 14]               0
#        BasicBlock-71          [-1, 256, 14, 14]               0
#            Conv2d-72          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-73          [-1, 256, 14, 14]             512
#              ReLU-74          [-1, 256, 14, 14]               0
#            Conv2d-75          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-76          [-1, 256, 14, 14]             512
#              ReLU-77          [-1, 256, 14, 14]               0
#        BasicBlock-78          [-1, 256, 14, 14]               0
#            Conv2d-79          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-80          [-1, 256, 14, 14]             512
#              ReLU-81          [-1, 256, 14, 14]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#        BasicBlock-85          [-1, 256, 14, 14]               0
#            Conv2d-86          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-87          [-1, 256, 14, 14]             512
#              ReLU-88          [-1, 256, 14, 14]               0
#            Conv2d-89          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-90          [-1, 256, 14, 14]             512
#              ReLU-91          [-1, 256, 14, 14]               0
#        BasicBlock-92          [-1, 256, 14, 14]               0
#            Conv2d-93          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-94          [-1, 256, 14, 14]             512
#              ReLU-95          [-1, 256, 14, 14]               0
#            Conv2d-96          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-97          [-1, 256, 14, 14]             512
#              ReLU-98          [-1, 256, 14, 14]               0
#        BasicBlock-99          [-1, 256, 14, 14]               0
#           Conv2d-100            [-1, 512, 7, 7]       1,179,648
#      BatchNorm2d-101            [-1, 512, 7, 7]           1,024
#             ReLU-102            [-1, 512, 7, 7]               0
#           Conv2d-103            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-104            [-1, 512, 7, 7]           1,024
#           Conv2d-105            [-1, 512, 7, 7]         131,072
#      BatchNorm2d-106            [-1, 512, 7, 7]           1,024
#             ReLU-107            [-1, 512, 7, 7]               0
#       BasicBlock-108            [-1, 512, 7, 7]               0
#           Conv2d-109            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-110            [-1, 512, 7, 7]           1,024
#             ReLU-111            [-1, 512, 7, 7]               0
#           Conv2d-112            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-113            [-1, 512, 7, 7]           1,024
#             ReLU-114            [-1, 512, 7, 7]               0
#       BasicBlock-115            [-1, 512, 7, 7]               0
#           Conv2d-116            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-117            [-1, 512, 7, 7]           1,024
#             ReLU-118            [-1, 512, 7, 7]               0
#           Conv2d-119            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-120            [-1, 512, 7, 7]           1,024
#             ReLU-121            [-1, 512, 7, 7]               0
#       BasicBlock-122            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-123            [-1, 512, 1, 1]               0
#           Linear-124                 [-1, 1000]         513,000
# ================================================================
# Total params: 21,797,672
# Trainable params: 21,797,672
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 96.29
# Params size (MB): 83.15
# Estimated Total Size (MB): 180.01
# ----------------------------------------------------------------

# %% [markdown]
# # Hyperparameters

# %%
# Hyperparameters
learning_rate = 0.001
num_epochs = 30

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # Train and Validate

# %%
# record the training and validation accuracy & loss
train_accuracy, train_loss = [], []
val_accuracy, val_loss = [], []

# %%
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    print(f'Epoch {epoch+1}/{num_epochs}')
    for idx, (images, labels) in enumerate(tqdm(train_loader)):
        images, labels = images.to(device), labels.to(device)
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # loss
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        # accuracy
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_accuracy.append(100 * correct / total)
    train_loss.append(running_loss / total)

    print(f'Training Loss: {train_loss[-1]:.4f}, Accuracy: {train_accuracy[-1]:.2f}%')
    
    # Validation
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for idx, (images, labels) in enumerate(val_loader):
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # loss
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            # accuracy
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_accuracy.append(100 * correct / total)
    val_loss.append(running_loss / total)

    print(f'Validation Loss: {val_loss[-1]:.4f}, Accuracy: {val_accuracy[-1]:.2f}%')
# Out:
# Epoch 1/30
#  27%|██▋       | 14/51 [00:05<00:10,  3.48it/s]

# %% [markdown]
# # Visualize the results

# %%
import numpy as np
import matplotlib.pyplot as plt

# plot the training and validation accuracy and loss
plt.figure(figsize=(10, 5))
# accuracy
plt.subplot(1, 2, 1)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
# loss
plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
# show
plt.show()

# %% [markdown]
# # Test

# %%
test_accuracy = 0
total = 0

model.eval()
with torch.no_grad():
    for idx, (images, labels) in enumerate(test_loader):
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        # accuracy
        total += labels.size(0)
        test_accuracy += (predicted == labels).sum().item()

print(f'Test Accuracy: {100 * test_accuracy / total:.2f}%')
# Out:
# Test Accuracy: 85.52%
